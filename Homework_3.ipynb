# %% [markdown]
# ## Задание 1

# %%
import pandas as pd

# %%
df = pd.read_csv('./kc_house_data.csv')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# ### 1.1 Создать новый признак price_per_sq_lot, который будет содержать среднюю стоимость за один кв. метр общей площади

# %%
df['price_per_sq_lot'] = df['price'] / df['sqft_lot']

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...        1180              0
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
# 3      5000     1.0           0     0  ...        1050            910
# 4      8080     1.0           0     0  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15  price_per_sq_lot
# 0        5650         39.274336
# 1        7639         74.288870
# 2        8062         18.000000
# 3        5000        120.800000
# 4        7503         63.118812
#
# [5 rows x 22 columns]

# %% [markdown]
# ### 1.2 Создать новый признак delta_renovated, который будет содержать разницу в годах между годом реновацией дома и годом постройки дома
# Если реновации дома не было, то в новом признаке поставьте 0

# %%
df['delta_renovated'] = df['yr_renovated'] - df['yr_built']

# %%
df.loc[df['delta_renovated'] < 0, 'delta_renovated'] = 0

# %%
df.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520 221,900.0         3        1.0         1180      5650     1.0
# 1  6414100192 538,000.0         3        2.2         2570      7242     2.0
# 2  5631500400 180,000.0         2        1.0          770     10000     1.0
# 3  2487200875 604,000.0         4        3.0         1960      5000     1.0
# 4  1954400510 510,000.0         3        2.0         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3  ...        1180              0      1955
# 1           0     0          3  ...        2170            400      1951
# 2           0     0          3  ...         770              0      1933
# 3           0     0          5  ...        1050            910      1965
# 4           0     0          3  ...        1680              0      1987
#
#    yr_renovated  sqft_living15  sqft_lot15  price_per_sq_lot  delta_renovated  \
# 0             0           1340        5650              39.3                0
# 1          1991           1690        7639              74.3               40
# 2             0           2720        8062              18.0                0
# 3             0           1360        5000             120.8                0
# 4             0           1800        7503              63.1                0
#
#    year  month
# 0  2014     10
# 1  2014     12
# 2  2015      2
# 3  2014     12
# 4  2015      2
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 1.3 Создайте признаки года продажи, месяца продажи

# %%
df['year'] = df['date'].apply(lambda x : int(x[:4]))

# %%
df['month'] = df['date'].apply(lambda x : int(x[4:6]))

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  yr_renovated  zipcode      lat  \
# 0      5650     1.0           0     0  ...             0    98178  47.5112
# 1      7242     2.0           0     0  ...          1991    98125  47.7210
# 2     10000     1.0           0     0  ...             0    98028  47.7379
# 3      5000     1.0           0     0  ...             0    98136  47.5208
# 4      8080     1.0           0     0  ...             0    98074  47.6168
#
#       long  sqft_living15  sqft_lot15  price_per_sq_lot  delta_renovated  \
# 0 -122.257           1340        5650         39.274336                0
# 1 -122.319           1690        7639         74.288870               40
# 2 -122.233           2720        8062         18.000000                0
# 3 -122.393           1360        5000        120.800000                0
# 4 -122.045           1800        7503         63.118812                0
#
#    year  month
# 0  2014     10
# 1  2014     12
# 2  2015      2
# 3  2014     12
# 4  2015      2
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                21613 non-null  int64
#  1   date              21613 non-null  object
#  2   price             21613 non-null  float64
#  3   bedrooms          21613 non-null  int64
#  4   bathrooms         21613 non-null  float64
#  5   sqft_living       21613 non-null  int64
#  6   sqft_lot          21613 non-null  int64
#  7   floors            21613 non-null  float64
#  8   waterfront        21613 non-null  int64
#  9   view              21613 non-null  int64
#  10  condition         21613 non-null  int64
#  11  grade             21613 non-null  int64
#  12  sqft_above        21613 non-null  int64
#  13  sqft_basement     21613 non-null  int64
#  14  yr_built          21613 non-null  int64
#  15  yr_renovated      21613 non-null  int64
#  16  zipcode           21613 non-null  int64
#  17  lat               21613 non-null  float64
#  18  long              21613 non-null  float64
#  19  sqft_living15     21613 non-null  int64
#  20  sqft_lot15        21613 non-null  int64
#  21  price_per_sq_lot  21613 non-null  float64
#  22  delta_renovated   21613 non-null  int64
#  23  year              21613 non-null  int64
#  24  month             21613 non-null  int64
# dtypes: float64(6), int64(18), object(1)
# memory usage: 4.1+ MB

# %% [markdown]
# ### 1.4 Удалите признаки date, zipcode, lat, long

# %%
df.drop(columns=['date','zipcode', 'lat', 'long'], inplace=True)

# %%
df.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3  ...        1180              0      1955
# 1           0     0          3  ...        2170            400      1951
# 2           0     0          3  ...         770              0      1933
# 3           0     0          5  ...        1050            910      1965
# 4           0     0          3  ...        1680              0      1987
#
#    yr_renovated  sqft_living15  sqft_lot15  price_per_sq_lot  delta_renovated  \
# 0             0           1340        5650         39.274336                0
# 1          1991           1690        7639         74.288870               40
# 2             0           2720        8062         18.000000                0
# 3             0           1360        5000        120.800000                0
# 4             0           1800        7503         63.118812                0
#
#    year  month
# 0  2014     10
# 1  2014     12
# 2  2015      2
# 3  2014     12
# 4  2015      2
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Задание 2

# %%
clients = pd.DataFrame({
    'client_id': [1459, 4684, 3498, 3942, 4535, 2308, 2866, 2765, 1472, 4236, 2295, 939, 3840,  280,   20, 4332, 3475, 4213, 3113, 4809, 2134, 2242, 2068, 4929, 1384, 1589, 3317, 2260, 1727, 1764, 1611, 1474],
    'house_id': [8965450190, 6823100225, 5104540330, 2131701075, 1522700060, 1189000207, 6821600300, 7137950720, 9510920050, 6131600255, 5428000070, 1788800910, 8100400160, 3123049142, 6306800010, 5083000375, 7920100025, 1951600150,  809001400,  339600110, 1622049154, 1099600250, 8563000110, 2768100205, 3995700435, 8861700030, 3303980210, 7731100066, 8146100580,  825069097, 3889100029, 9524100196]
})

# %% [markdown]
# ### 2.1 Присоедините к таблице clients данные по домам через метод join

# %%
clients_id = clients.set_index('house_id')

# %%
df_id = df.set_index('id')

# %%
clients.join(df).head()
# Out:
#    client_id    house_id          id     price  bedrooms  bathrooms  \
# 0       1459  8965450190  7129300520  221900.0         3       1.00
# 1       4684  6823100225  6414100192  538000.0         3       2.25
# 2       3498  5104540330  5631500400  180000.0         2       1.00
# 3       3942  2131701075  2487200875  604000.0         4       3.00
# 4       4535  1522700060  1954400510  510000.0         3       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  sqft_above  sqft_basement  \
# 0         1180      5650     1.0           0  ...        1180              0
# 1         2570      7242     2.0           0  ...        2170            400
# 2          770     10000     1.0           0  ...         770              0
# 3         1960      5000     1.0           0  ...        1050            910
# 4         1680      8080     1.0           0  ...        1680              0
#
#    yr_built  yr_renovated  sqft_living15  sqft_lot15  price_per_sq_lot  \
# 0      1955             0           1340        5650         39.274336
# 1      1951          1991           1690        7639         74.288870
# 2      1933             0           2720        8062         18.000000
# 3      1965             0           1360        5000        120.800000
# 4      1987             0           1800        7503         63.118812
#
#    delta_renovated  year  month
# 0                0  2014     10
# 1               40  2014     12
# 2                0  2015      2
# 3                0  2014     12
# 4                0  2015      2
#
# [5 rows x 23 columns]

# %% [markdown]
# ### 2.2 Присоедините к таблице clients данные по домам через метод merge

# %%
clients.merge(df, left_on='house_id', right_on='id').head()
# Out:
#    client_id    house_id          id     price  bedrooms  bathrooms  \
# 0       1459  8965450190  8965450190  295000.0         3       2.50
# 1       4684  6823100225  6823100225  700000.0         4       1.75
# 2       3498  5104540330  5104540330  679000.0         4       2.50
# 3       3942  2131701075  2131701075  420000.0         3       1.75
# 4       4535  1522700060  1522700060  518000.0         4       2.75
#
#    sqft_living  sqft_lot  floors  waterfront  ...  sqft_above  sqft_basement  \
# 0         1500      3060     2.0           0  ...        1500              0
# 1         1870      6000     1.0           0  ...        1670            200
# 2         3680      7236     2.0           0  ...        3680              0
# 3         1720      5000     1.5           0  ...        1720              0
# 4         2520     14021     2.0           0  ...        2520              0
#
#    yr_built  yr_renovated  sqft_living15  sqft_lot15  price_per_sq_lot  \
# 0      1994             0           2700        7734         96.405229
# 1      1949             0           1710        6000        116.666667
# 2      2006             0           3310        7180         93.836374
# 3      1932          2009           1410        8300         84.000000
# 4      1999             0           2330       14007         36.944583
#
#    delta_renovated  year  month
# 0                0  2015      2
# 1                0  2015      4
# 2                0  2015      5
# 3               77  2014     12
# 4                0  2014      6
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Задание 3
# Составьте несколько сводных таблиц

# %% [markdown]
# ### 3.1 Найдите среднюю стоимость домов в зависимости от количества спален
# Отсортируйте от меньшей стоимости к большей

# %%
pd.options.display.float_format ='{:,.0f}'.format

# %%
df.groupby('bedrooms').agg({'price' : 'mean'})
# Out:
#              price
# bedrooms
# 0          409,504
# 1          317,643
# 2          401,373
# 3          466,232
# 4          635,420
# 5          786,600
# 6          825,521
# 7          951,185
# 8        1,105,077
# 9          894,000
# 10         819,333
# 11         520,000
# 33         640,000

# %% [markdown]
# ### 3.2 Найдите минимальную, среднюю и максимальную стоимости домов в зависимости от состояния дома

# %%
df.groupby('condition').agg({'price' : ['min', 'mean', 'max']})
# Out:
#             price
#               min    mean       max
# condition
# 1          78,000 334,432 1,500,000
# 2          80,000 327,287 2,555,000
# 3          75,000 542,013 7,062,500
# 4          89,000 521,200 7,700,000
# 5         110,000 612,418 3,650,000

# %% [markdown]
# ### 3.3 Постройте таблицу с подсчетом количества домов в данных в зависимости от вида на набережную и оценкой вида

# %%
df.pivot_table(index='view',
              columns='waterfront',
                values='id',
              aggfunc='count',
              fill_value='--')
# Out:
# waterfront      0   1
# view
# 0           19489  --
# 1             331   1
# 2             955   8
# 3             491  19
# 4             184 135

# %% [markdown]
# ### 3.4 Каких домов в зависимости от этажности и количества спален больше?

# %%
pd.options.display.float_format ='{:,.1f}'.format

# %%
data = pd.crosstab(index=df['bedrooms'],
              columns=df['floors']).fillna('--')

# %%
data
# Out:
# floors     1.0  1.5   2.0  2.5  3.0  3.5
# bedrooms
# 0            4    0     6    0    2    1
# 1          162   21    12    1    3    0
# 2         1951  182   497    5  123    2
# 3         5455  786  3118   56  405    4
# 4         2383  698  3682   58   61    0
# 5          605  185   775   23   13    0
# 6          104   30   119   14    5    0
# 7            9    7    19    2    1    0
# 8            5    1     6    0    0    1
# 9            0    0     4    2    0    0
# 10           1    0     2    0    0    0
# 11           0    0     1    0    0    0
# 33           1    0     0    0    0    0

# %%
def gold_max(x):
    m = x.to_numpy().max()
    color = {True: "background-color: #c78f2e", False: ""}
    is_max = (x == m).replace(color)
    return is_max

# %%
data.style.apply(gold_max, axis = None)
# Out:
# <style type="text/css">
# #T_8791e_row3_col0 {
#   background-color: #c78f2e;
# }
# </style>
# <table id="T_8791e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >floors</th>
#       <th id="T_8791e_level0_col0" class="col_heading level0 col0" >1.000000</th>
#       <th id="T_8791e_level0_col1" class="col_heading level0 col1" >1.500000</th>
#       <th id="T_8791e_level0_col2" class="col_heading level0 col2" >2.000000</th>
#       <th id="T_8791e_level0_col3" class="col_heading level0 col3" >2.500000</th>
#       <th id="T_8791e_level0_col4" class="col_heading level0 col4" >3.000000</th>
#       <th id="T_8791e_level0_col5" class="col_heading level0 col5" >3.500000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >bedrooms</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8791e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8791e_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_8791e_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_8791e_row0_col2" class="data row0 col2" >6</td>
#       <td id="T_8791e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_8791e_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_8791e_row0_col5" class="data row0 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8791e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8791e_row1_col0" class="data row1 col0" >162</td>
#       <td id="T_8791e_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_8791e_row1_col2" class="data row1 col2" >12</td>
#       <td id="T_8791e_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_8791e_row1_col4" class="data row1 col4" >3</td>
#       <td id="T_8791e_row1_col5" class="data row1 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8791e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8791e_row2_col0" class="data row2 col0" >1951</td>
#       <td id="T_8791e_row2_col1" class="data row2 col1" >182</td>
#       <td id="T_8791e_row2_col2" class="data row2 col2" >497</td>
#       <td id="T_8791e_row2_col3" class="data row2 col3" >5</td>
#       <td id="T_8791e_row2_col4" class="data row2 col4" >123</td>
#       <td id="T_8791e_row2_col5" class="data row2 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_8791e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8791e_row3_col0" class="data row3 col0" >5455</td>
#       <td id="T_8791e_row3_col1" class="data row3 col1" >786</td>
#       <td id="T_8791e_row3_col2" class="data row3 col2" >3118</td>
#       <td id="T_8791e_row3_col3" class="data row3 col3" >56</td>
#       <td id="T_8791e_row3_col4" class="data row3 col4" >405</td>
#       <td id="T_8791e_row3_col5" class="data row3 col5" >4</td>
#     </tr>
#     <tr>
#       <th id="T_8791e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8791e_row4_col0" class="data row4 col0" >2383</td>
#       <td id="T_8791e_row4_col1" class="data row4 col1" >698</td>
#       <td id="T_8791e_row4_col2" class="data row4 col2" >3682</td>
#       <td id="T_8791e_row4_col3" class="data row4 col3" >58</td>
#       <td id="T_8791e_row4_col4" class="data row4 col4" >61</td>
#       <td id="T_8791e_row4_col5" class="data row4 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8791e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8791e_row5_col0" class="data row5 col0" >605</td>
#       <td id="T_8791e_row5_col1" class="data row5 col1" >185</td>
#       <td id="T_8791e_row5_col2" class="data row5 col2" >775</td>
#       <td id="T_8791e_row5_col3" class="data row5 col3" >23</td>
#       <td id="T_8791e_row5_col4" class="data row5 col4" >13</td>
#       <td id="T_8791e_row5_col5" class="data row5 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8791e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8791e_row6_col0" class="data row6 col0" >104</td>
#       <td id="T_8791e_row6_col1" class="data row6 col1" >30</td>
#       <td id="T_8791e_row6_col2" class="data row6 col2" >119</td>
#       <td id="T_8791e_row6_col3" class="data row6 col3" >14</td>
#       <td id="T_8791e_row6_col4" class="data row6 col4" >5</td>
#       <td id="T_8791e_row6_col5" class="data row6 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8791e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8791e_row7_col0" class="data row7 col0" >9</td>
#       <td id="T_8791e_row7_col1" class="data row7 col1" >7</td>
#       <td id="T_8791e_row7_col2" class="data row7 col2" >19</td>
#       <td id="T_8791e_row7_col3" class="data row7 col3" >2</td>
#       <td id="T_8791e_row7_col4" class="data row7 col4" >1</td>
#       <td id="T_8791e_row7_col5" class="data row7 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8791e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8791e_row8_col0" class="data row8 col0" >5</td>
#       <td id="T_8791e_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_8791e_row8_col2" class="data row8 col2" >6</td>
#       <td id="T_8791e_row8_col3" class="data row8 col3" >0</td>
#       <td id="T_8791e_row8_col4" class="data row8 col4" >0</td>
#       <td id="T_8791e_row8_col5" class="data row8 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8791e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8791e_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_8791e_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_8791e_row9_col2" class="data row9 col2" >4</td>
#       <td id="T_8791e_row9_col3" class="data row9 col3" >2</td>
#       <td id="T_8791e_row9_col4" class="data row9 col4" >0</td>
#       <td id="T_8791e_row9_col5" class="data row9 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8791e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8791e_row10_col0" class="data row10 col0" >1</td>
#       <td id="T_8791e_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_8791e_row10_col2" class="data row10 col2" >2</td>
#       <td id="T_8791e_row10_col3" class="data row10 col3" >0</td>
#       <td id="T_8791e_row10_col4" class="data row10 col4" >0</td>
#       <td id="T_8791e_row10_col5" class="data row10 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8791e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8791e_row11_col0" class="data row11 col0" >0</td>
#       <td id="T_8791e_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_8791e_row11_col2" class="data row11 col2" >1</td>
#       <td id="T_8791e_row11_col3" class="data row11 col3" >0</td>
#       <td id="T_8791e_row11_col4" class="data row11 col4" >0</td>
#       <td id="T_8791e_row11_col5" class="data row11 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8791e_level0_row12" class="row_heading level0 row12" >33</th>
#       <td id="T_8791e_row12_col0" class="data row12 col0" >1</td>
#       <td id="T_8791e_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_8791e_row12_col2" class="data row12 col2" >0</td>
#       <td id="T_8791e_row12_col3" class="data row12 col3" >0</td>
#       <td id="T_8791e_row12_col4" class="data row12 col4" >0</td>
#       <td id="T_8791e_row12_col5" class="data row12 col5" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Больше всего домов с 3 спальнями в один этаж.

# %% [markdown]
# ### 3.5 Постройте таблицу с подсчетом медианной стоимости домов в данных в зависимости от состояния дома и оценки дома

# %%
df.pivot_table(index='condition',
              columns='grade',
              values='price',
              aggfunc='median',
              fill_value='--')
# Out:
# grade            1         3         4       5       6       7       8   \
# condition
# 1         142,000.0        -- 150,000.0  190000  255000  403500  932500
# 2                -- 280,000.0 145,000.0  180000  235000  305000  429000
# 3                --  75,000.0 205,000.0  234475  265000  357500  485000
# 4                --        -- 238,525.0  229975  295000  390000  571250
# 5                -- 262,000.0        --  227450  285475  456000  696000
#
# grade              9           10          11          12          13
# condition
# 1                  --          --          --          --          --
# 2           715,000.0 1,752,500.0          --          --          --
# 3           689,000.0   890,000.0 1,209,500.0 1,807,500.0 2,888,000.0
# 4           823,500.0 1,030,000.0 1,685,000.0 2,125,000.0 5,750,000.0
# 5         1,078,000.0 1,650,000.0 2,050,000.0 1,990,000.0          --
